# %%
import pandas as pd
from pandas import Series, DataFrame
import numpy as np
from numpy.random import randn

# %%
import matplotlib as mpl 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# example of markdown

# %%
url = 'http://en.wikipedia.org/wiki/Histogram'

# %%
dataset1 = randn(100)

# %%
plt.hist(dataset1)
# Out:
# (array([ 3.,  1., 12., 16., 20., 21., 13.,  7.,  3.,  4.]),
#  array([-2.57801303e+00, -2.06194929e+00, -1.54588556e+00, -1.02982183e+00,
#         -5.13758096e-01,  2.30563713e-03,  5.18369370e-01,  1.03443310e+00,
#          1.55049684e+00,  2.06656057e+00,  2.58262430e+00]),
#  <a list of 10 Patch objects>)

# %%
dataset2 = randn(80)

# %%
plt.hist(dataset1,density=True,color='indianred',alpha=0.5,bins=20)
plt.hist(dataset2,density=True,alpha=0.5,bins=20)
# Out:
# (array([0.08468608, 0.        , 0.04234304, 0.08468608, 0.08468608,
#         0.2117152 , 0.16937216, 0.2117152 , 0.33874432, 0.4234304 ,
#         0.50811649, 0.38108736, 0.29640128, 0.2117152 , 0.2117152 ,
#         0.        , 0.04234304, 0.04234304, 0.        , 0.04234304]),
#  array([-2.92985994, -2.63465204, -2.33944414, -2.04423624, -1.74902834,
#         -1.45382044, -1.15861254, -0.86340464, -0.56819674, -0.27298884,
#          0.02221905,  0.31742695,  0.61263485,  0.90784275,  1.20305065,
#          1.49825855,  1.79346645,  2.08867435,  2.38388225,  2.67909014,
#          2.97429804]),
#  <a list of 20 Patch objects>)

# %%
data1 = randn(1000)
data2 = randn(1000)

# %%
sns.jointplot(data1,data2)

# %%
sns.jointplot(data1,data2 ,kind='hex')
